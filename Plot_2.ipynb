# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
with open('HMN_history.pickle', 'rb') as handle:
    hmn = pickle.load(handle)
with open('fusion_history.pickle', 'rb') as handle:
    fusion = pickle.load(handle)
with open('CoA_Res_history.pickle', 'rb') as handle:
    res = pickle.load(handle)
with open('CoA_Res_history_2.pickle', 'rb') as handle:
    res2 = pickle.load(handle)
with open('DrQA_history.pickle', 'rb') as handle:
    drqa = pickle.load(handle)

# %%
hmn.keys()
# Out:
# ['val_activation_84_acc',
#  'loss',
#  'activation_84_loss',
#  'activation_85_loss',
#  'activation_85_acc',
#  'activation_84_acc',
#  'val_activation_85_acc',
#  'val_activation_84_loss',
#  'val_activation_85_loss',
#  'val_loss']

# %%
fusion.keys()
# Out:
# ['start_loss',
#  'loss',
#  'val_end_acc',
#  'val_end_loss',
#  'val_start_acc',
#  'end_loss',
#  'val_start_loss',
#  'start_acc',
#  'val_loss',
#  'end_acc']

# %%
res.keys()
# Out:
# ['loss',
#  'output_1_acc',
#  'output_1_loss',
#  'output_2_loss',
#  'val_output_1_acc',
#  'val_output_1_loss',
#  'val_output_2_loss',
#  'val_output_2_acc',
#  'val_loss',
#  'output_2_acc']

# %%
drqa.keys()
# Out:
# ['activation_21_loss',
#  'loss',
#  'activation_20_acc',
#  'val_activation_20_loss',
#  'val_activation_21_acc',
#  'val_activation_21_loss',
#  'activation_21_acc',
#  'val_loss',
#  'val_activation_20_acc',
#  'activation_20_loss']

# %%
# summarize history for accuracy  
plt.figure(1)  
plt.plot(drqa['activation_20_acc']) 
plt.plot(fusion['start_acc']) 
plt.plot(hmn['activation_84_acc'])  
plt.plot(res2['output_1_acc'][0:10])  
# plt.plot(a['val_start_acc'])  
plt.title('Training Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['DrQA', 'Fusion', 'CoA-HMN', 'CoA-Res'], loc='upper left')  
plt.show()    
# summarize history for loss  
plt.figure(2)  
plt.plot(drqa['loss']) 
plt.plot(fusion['loss']) 
plt.plot(hmn['loss'])  
plt.plot(res2['loss'][0:10])  
plt.title('Training Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['DrQA', 'Fusion', 'CoA-HMN', 'CoA-Res'], loc='upper right')  
plt.show()

# %%
# summarize history for accuracy  
plt.figure(1)  
plt.plot(drqa['val_activation_20_acc']) 
plt.plot(fusion['val_start_acc']) 
plt.plot(hmn['val_activation_84_acc'])  
plt.plot(res2['val_output_1_acc'][0:10])  
# plt.plot(a['val_start_acc'])  
plt.title('Validation Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['DrQA', 'Fusion', 'CoA-HMN', 'CoA-Res'], loc='upper left')  
plt.show()    
# summarize history for loss  
plt.figure(2)  
plt.plot(drqa['val_loss']) 
plt.plot(fusion['val_loss']) 
plt.plot(hmn['val_loss'])  
plt.plot(res2['val_loss'][0:10])  
plt.title('Validation Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['DrQA', 'Fusion', 'CoA-HMN', 'CoA-Res'], loc='upper right')  
plt.show()

# %%
# summarize history for accuracy  
plt.figure(1)  
plt.plot(drqa['val_activation_20_acc']) 
plt.plot(fusion['val_start_acc']) 
plt.plot(hmn['val_activation_84_acc'])  
plt.plot(res2['val_output_1_acc'])  
# plt.plot(a['val_start_acc'])  
plt.title('Validation Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['DrQA', 'Fusion', 'CoA-HMN', 'CoA-Res'], loc='upper right')  
plt.show()    
# summarize history for loss  
plt.figure(2)  
plt.plot(drqa['val_loss']) 
plt.plot(fusion['val_loss']) 
plt.plot(hmn['val_loss'])  
plt.plot(res2['val_loss'])  
plt.title('Validation Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['DrQA', 'Fusion', 'CoA-HMN', 'CoA-Res'], loc='lower right')  
plt.show()

# %%
# summarize history for accuracy  
plt.figure(1)  
plt.plot(drqa['activation_20_acc']) 
plt.plot(fusion['start_acc']) 
plt.plot(hmn['activation_84_acc'])  
plt.plot(res2['output_1_acc'])  
# plt.plot(a['val_start_acc'])  
plt.title('Training Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['DrQA', 'Fusion', 'CoA-HMN', 'CoA-Res'], loc='upper right')  
plt.show()    
# summarize history for loss  
plt.figure(2)  
plt.plot(drqa['loss']) 
plt.plot(fusion['loss']) 
plt.plot(hmn['loss'])  
plt.plot(res2['loss'])  
plt.title('Training Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['DrQA', 'Fusion', 'CoA-HMN', 'CoA-Res'], loc='upper right')  
plt.show()
